# %% [markdown]
# # Mekong Flood Intelligence — Level 3 (plan v1.1, RTC)
#
# Two cells. Everything else lives in the repo (`scripts/colab_run.py`), which is pulled fresh each run, so this notebook cannot go stale.
#
# **Before running:**
# 1. Upload `data/colab/chip_cache_rtc.zip` (0.65 GB) to Google Drive at `MyDrive/mfi/`
# 2. Runtime → Change runtime type → **GPU (T4)**
# 3. Colab Secrets (🔑) → `GITHUB_TOKEN` with notebook access on
#
# Then Runtime → Run all. Takes ~1.5–2 h. Test is never scored here.

# %%
# !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader
import os
REPO = '/content/mekong-flood-analysis'
if not os.path.isdir(REPO):
    # !git clone --quiet https://github.com/SoSereysokbotra/mekong-flood-analysis.git {REPO}
# %cd {REPO}
# !git checkout --quiet -- . && git pull --quiet origin main && git log --oneline | head -1
# !pip install -q rasterio pystac-client planetary-computer segmentation-models-pytorch pyyaml scikit-image
from google.colab import drive
drive.mount('/content/drive')

# %%
# the token must be read in the notebook kernel and exported; a subprocess cannot read Colab secrets
import os
try:
    from google.colab import userdata
    os.environ['GITHUB_TOKEN'] = userdata.get('GITHUB_TOKEN')
except Exception as e:
    print('no GITHUB_TOKEN secret (results will not be pushed):', e)

# !python scripts/colab_run.py
